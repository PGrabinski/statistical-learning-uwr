# %%
set.seed(42)
install.packages("ggplot2")
library(ggplot2)
install.packages("ellipse")
library(ellipse)
install.packages("patchwork")
library(patchwork)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
#
# Attaching package: ‘ellipse’
#
#
# The following object is masked from ‘package:graphics’:
#
#     pairs
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
parent_data <- read.table("ParentsWeightLength.txt", header=TRUE)

# %%
parent_data
# Out:
#     FatherHeight MotherHeight Weight Length
# 1   176.7        172.8        3676.9 51.6
# 2   175.1        164.0        2828.1 48.2
# 3   178.8        169.1        3853.5 51.8
# 4   183.9        170.0        3815.3 51.3
# 5   178.1        166.9        3558.8 50.3
# 6   175.2        167.4        2937.5 47.4
# 7   177.6        162.7        2689.1 48.3
# 8   179.0        164.6        3108.9 49.0
# 9   178.6        162.8        3272.1 49.2
# 10  175.6        172.8        3486.2 50.3
# 11  168.2        169.1        3195.6 51.1
# 12  170.0        163.9        2345.6 45.2
# 13  171.9        165.7        2687.0 47.6
# 14  176.4        167.8        2940.1 48.5
# 15  177.3        167.8        3111.5 48.4
# 16  180.1        163.6        3703.0 52.0
# 17  179.1        167.3        3744.6 53.0
# 18  177.9        170.2        3992.4 52.9
# 19  173.7        165.1        2760.7 47.1
# 20  179.5        164.9        3102.4 49.0
# 21  181.5        165.2        3382.9 49.8
# 22  174.3        172.0        3449.6 49.5
# 23  174.3        168.6        3121.9 48.9
# 24  172.4        161.5        1939.6 43.5
# 25  176.0        173.2        3776.1 51.3
# 26  173.1        168.8        3536.2 50.9
# 27  182.7        168.7        3868.4 51.9
# 28  182.8        168.9        3620.9 51.0
# 29  179.3        166.6        3788.3 52.3
# 30  177.6        171.1        3561.2 49.2
# ⋮   ⋮            ⋮            ⋮      ⋮
# 707 179.6        174.5        4081.1 51.7
# 708 173.2        167.5        3195.6 50.0
# 709 179.5        163.6        3279.7 50.0
# 710 175.2        167.1        2903.1 47.1
# 711 173.4        167.8        2927.1 47.9
# 712 183.9        167.1        3983.8 52.3
# 713 174.0        166.1        2866.8 47.9
# 714 176.6        165.5        3321.9 49.6
# 715 176.8        165.7        3436.3 51.8
# 716 177.4        168.9        3424.2 48.7
# 717 184.9        169.0        4095.4 53.2
# 718 180.9        167.0        3811.2 51.3
# 719 177.6        172.6        3548.4 48.5
# 720 175.8        166.2        2608.4 45.8
# 721 176.2        167.2        3449.1 50.2
# 722 173.3        158.8        2264.2 46.4
# 723 181.9        166.5        3912.8 52.3
# 724 182.0        165.5        3493.2 50.4
# 725 168.3        165.4        2948.5 49.0
# 726 179.1        167.7        3624.7 50.9
# 727 174.9        165.6        2822.6 48.5
# 728 176.3        168.2        3347.7 49.8
# 729 183.2        164.1        3024.6 48.4
# 730 180.5        161.8        3038.8 48.2
# 731 173.3        165.1        2806.6 47.3
# 732 182.2        172.1        4193.1 52.6
# 733 184.0        169.9        3862.4 51.7
# 734 173.6        169.9        3575.0 51.9
# 735 173.5        171.6        3392.7 49.8
# 736 172.8        167.7        2876.3 48.2

# %%
means <- colMeans(parent_data)
means
# Out:
# FatherHeight MotherHeight       Weight       Length
#    177.41603    166.91957   3233.54511     49.23764

# %%
covariance <- cov(parent_data)
covariance
# Out:
#              FatherHeight MotherHeight Weight      Length
# FatherHeight  12.6120963    0.6310056     931.8590   3.289545
# MotherHeight   0.6310056    9.7721065     827.2878   2.852147
# Weight       931.8589629  827.2877829  220276.6577 915.295511
# Length         3.2895454    2.8521470     915.2955   4.443303

# %%
cor(parent_data)
# Out:
#              FatherHeight MotherHeight Weight    Length
# FatherHeight 1.00000000   0.05683888   0.5590779 0.4394296
# MotherHeight 0.05683888   1.00000000   0.5638691 0.4328375
# Weight       0.55907788   0.56386907   1.0000000 0.9251755
# Length       0.43942959   0.43283748   0.9251755 1.0000000

# %%
qqnorm(parent_data[["Weight"]])
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
qqnorm(parent_data[["Length"]])
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
qqnorm(parent_data[["FatherHeight"]])
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
qqnorm(parent_data[["MotherHeight"]])
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
plot(parent_data["Weight"], parent_data["Length"])
# Out:
# Error in stripchart.default(x1, ...): invalid plotting method
# Traceback:
#
# 1. plot(parent_data["Weight"], parent_data["Length"])
# 2. plot.data.frame(parent_data["Weight"], parent_data["Length"])
# 3. stripchart(x1, ...)
# 4. stripchart.default(x1, ...)
# 5. stop("invalid plotting method")
